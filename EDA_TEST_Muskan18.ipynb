# %% [markdown]
# <H1>EXPLORATORY DATA ANALYSIS</H1>

# %% [markdown]
# <H2>AMAZON SALES DATA</H2>

# %% [markdown]
# QUES 1:What is the average rating for each product category?

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd
df=pd.read_csv("amazon.csv")
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df["rating"]=pd.to_numeric(df["rating"],errors="coerce")  
average_rating=df.groupby("category")["rating"].mean().sort_values(ascending=False)
print(average_rating)
# Out:
# category
# Computers&Accessories|Tablets                                                                                    4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters                                         4.5
# Electronics|Cameras&Photography|Accessories|Film                                                                 4.5
# Computers&Accessories|Components|Memory                                                                          4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                                                     4.5
#                                                                                                                 ...
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                               3.6
# Electronics|HomeTheater,TV&Video|Accessories|3DGlasses                                                           3.5
# ...

# %% [markdown]
# QUES2:What are the top rating_count products by category?

# %% [markdown]
# <B>ANS:</B>

# %%
top_rating_count=df.sort_values("rating_count",ascending=False)[
  ["product_name","category","rating","rating_count"]
].head(5)
print(top_rating_count)
# Out:
#                                            product_name  \
# 1279  Eureka Forbes car Vac 100 Watts Powerful Sucti...
# 750        Eveready Red 1012 AAA Batteries - Pack of 10
# 977   Sennheiser CX 80S in-Ear Wired Headphones with...
# 1059  Pigeon 1.5 litre Hot Kettle and Stainless Stee...
# 151   Zoul USB Type C Fast Charging 3A Nylon Braided...
#
#                                                category rating rating_count
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...      |          992
# 750   Electronics|GeneralPurposeBatteries&BatteryCha...    4.3          989
# 977   Electronics|Headphones,Earbuds&Accessories|Hea...    4.1       98,250
# 1059  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...    3.7          976
# 151   Computers&Accessories|Accessories&Peripherals|...    4.3          974

# %% [markdown]
# QUES3: What is the distribution of discounted prices vs. actual prices?

# %% [markdown]
# <B>ANS:</B>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["actual_price"],alpha =0.5,label ="Actual Price")
plt.hist(df["discounted_price"],alpha =0.5,label ="Discounted Price")
plt.legend()
plt.title("Price Distribution")
plt.show()

# %% [markdown]
# QUES4: How does the average discount percentage vary across categories?

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("amazon.csv")

df["discount_percentage"] = df["discount_percentage"].str.replace('%','').astype(float)
avg_discount = df.groupby("category")["discount_percentage"].mean().sort_values(ascending=False)

print(avg_discount)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors                            90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                                                                    90.0
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms                                                   90.0
# Electronics|Headphones,Earbuds&Accessories|Adapters                                                                   88.0
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers         87.5
#                                                                                                                       ...
# OfficeProducts|OfficeElectronics|Calculators|Financial&Business                                                        0.0
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=avg_discount.index, y=avg_discount.values)

plt.xticks(rotation=45)
plt.title("Average Discount % Across Categories")
plt.xlabel("Category")
plt.ylabel("Average Discount (%)")
plt.show()

# %% [markdown]
# QUES5. What are the most popular product names?

# %% [markdown]
# <B>ANS:</B>

# %%
df["product_name"].value_counts().head(10)
# Out:
# product_name
# Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution                                                  5
# Fire-Boltt Phoenix Smart Watch with Bluetooth Calling 1.3",120+ Sports Modes, 240*240 PX High Res with SpO2, Heart Rate Monitoring & IP67 Rating                                                           4
# Amazonbasics Nylon Braided Usb-C To Lightning Cable, Fast Charging Mfi Certified Smartphone, Iphone Charger (6-Foot, Dark Grey)                                                                            3
# Duracell USB Lightning Apple Certified (Mfi) Braided Sync & Charge Cable For Iphone, Ipad And Ipod. Fast Charging Lightning Cable, 3.9 Feet (1.2M) - Black                                                 3
# ...

# %%
import pandas as pd
df = pd.read_csv("amazon.csv")
df["rating_count"] = df["rating_count"].str.replace(',', '').astype(float)

top_products = (
    df.sort_values(by="rating_count", ascending=False)
      [["product_name", "rating_count"]].head(10)
)

print("Top 10 Most Popular Products (By Rating Count):")
print(top_products)
# Out:
# Top 10 Most Popular Products (By Rating Count):
#                                           product_name  rating_count
# 47   Amazon Basics High-Speed HDMI Cable, 6 Feet - ...      426973.0
# 65   Amazon Basics High-Speed HDMI Cable, 6 Feet (2...      426973.0
# 12   AmazonBasics Flexible Premium HDMI Cable (Blac...      426973.0
# 684  AmazonBasics Flexible Premium HDMI Cable (Blac...      426972.0
# 400  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 352  boAt Bassheads 100 in Ear Wired Earphones with...      363713.0
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...      363711.0
# 371  Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Sto...      313836.0
# 370  Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Sto...      313836.0
# 566  Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Sto...      313832.0

# %% [markdown]
# QUES6. What are the most popular product keywords?

# %% [markdown]
# <B>ANS:</B>

# %%
from collections import Counter

#Combine all text
text=" ".join(df["about_product"].dropna())
words =text.lower().split()
Counter(words).most_common(10)
# Out:
# [('and', 5260),
#  ('the', 4335),
#  ('to', 3777),
#  ('with', 3086),
#  ('for', 2554),
#  ('of', 2099),
#  ('a', 1876),
#  ('your', 1867),
#  ('is', 1480),
#  ('|', 1431)]

# %% [markdown]
# QUES7: What are the most popular product reviews?

# %% [markdown]
# <B>ANS:</B>

# %%
df["review_title"].value_counts().head(10)
# Out:
# review_title
# Worked on iPhone 7 and didn’t work on XR,Good one,Dull Physical Looks,Just Buy it,Go for it,About the product,Get charging cable at the price,Working well.                                                                                                                                     10
# Satisfied,Charging is really fast,Value for money,Product review,Good quality,Good product,Good Product,As of now seems good                                                                                                                                                                     8
# Phone, camera, heating - works for me, may not for all,Good Mobile,Good but not excellent under this budget,Worth the price at 9499,Ok type phone... but unable to make videocall within same service provider.,Phone review,Budget king,Battery backup is good                                  8
# ...

# %% [markdown]
# QUES8. What is the correlation between discounted_price and rating?

# %% [markdown]
# <B>ANS:</B>

# %%
print(df[["discounted_price", "rating"]].dtypes)
# Out:
# discounted_price     object
# rating              float64
# dtype: object

# %%
df["discounted_price"] = pd.to_numeric(df["discounted_price"], errors="coerce")
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# %%
correlation = df["discounted_price"].corr(df["rating"])
print("Correlation:", correlation)
# Out:
# Correlation: nan

# %% [markdown]
# QUES9. What are the Top 5 categories based on the highest ratings?

# %% [markdown]
# <B>ANS:</B>

# %%
df.groupby("category")["rating"].mean()\
  .sort_values(ascending=False).head(6)
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Computers&Accessories|Components|Memory                                     4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Name: rating, dtype: float64

# %% [markdown]
# QUES10. Identify any potential areas for improvement or optimization based on the data analysis.

# %% [markdown]
# <B>ANS:</B>

# %%
 1) Some products have low ratings and bad reviews.
 The company should check what customers are complaining about and improve the product quality.

 2)Some products have very high discounts but still don’t sell much.
 Instead of giving big discounts everywhere, focus discounts only where needed.

# %% [markdown]
# <H2> SPOTIFY DATASET </H2>

# %% [markdown]
# QUES1. Load the dataframe and ensure data quality by checking for missing values and
# duplicate rows. Handle missing values and remove duplicate rows if necessary.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd

df = pd.read_csv("spotify.csv")   
print(df.head())
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB
# None
#        Popularity  Duration (ms)
# count  440.000000     440.000000
# mean    75.736364  206810.040909
# std      9.886534   53576.930289
# min     29.000000   81666.000000
# 25%     70.000000  172778.500000
# 50%     77.000000  201866.000000
# 75%     83.000000  235119.750000
# max     97.000000  501648.000000

# %%
print(df.isnull().sum())
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 27

# %%
df = df.drop_duplicates()
print(df)
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 433  French Montana                                       Stand United
# 434    Jason Derulo                     Tip Toe (feat. French Montana)
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
print(df.isnull().sum())
print("Duplicate rows after cleaning:", df.duplicated().sum())
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64
# Duplicate rows after cleaning: 0

# %% [markdown]
# QUES2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a
# histogram.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("spotify.csv")  

# Check column names
print(df.columns)

# Ensure popularity is numeric
df["Popularity"] = pd.to_numeric(df["Popularity"], errors="coerce")

# Drop missing values
popularity = df["Popularity"].dropna()

# Create histogram
plt.figure()
plt.hist(popularity, bins=20)
plt.xlabel("Popularity")
plt.ylabel("Frequency")
plt.title("Distribution of Track Popularity")
plt.show()

# Summary statistics
print(popularity.describe())
# Out:
# Index(['Artist', 'Track Name', 'Popularity', 'Duration (ms)', 'Track ID'], dtype='object')
# count    440.000000
# mean      75.736364
# std        9.886534
# min       29.000000
# 25%       70.000000
# 50%       77.000000
# 75%       83.000000
# max       97.000000
# Name: Popularity, dtype: float64

# %% [markdown]
# QUES3. Is there any relationship between the popularity and the duration of tracks? Explore this
# using a scatter plot.

# %% [markdown]
# <B>ANS:</B>

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("spotify.csv")   
plt.figure()
plt.scatter(df["Duration (ms)"], df["Popularity"])


plt.xlabel("Duration (ms)")
plt.ylabel("Popularity")
plt.title("Popularity vs Duration of Tracks")

plt.show()

# %% [markdown]
# QUES4. Which artist has the highest number of tracks in the dataset? Display the count of tracks
# for each artist using a countplot.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("spotify.csv") 
artist_counts = df['Artist'].value_counts()

print(artist_counts)
# Out:
# Artist
# Drake           20
# Travis Scott    12
# 21 Savage       11
# Lil Nas X       11
# Eminem          11
#                 ..
# Lil Tjay         1
# BigXthaPlug      1
# Fat Joe          1
# A$AP Ferg        1
# Diddy            1
# Name: count, Length: 115, dtype: int64

# %%
top_artist = artist_counts.idxmax()
top_count = artist_counts.max()

print("Artist with highest number of tracks:", top_artist)
print("Number of tracks:", top_count)
# Out:
# Artist with highest number of tracks: Drake
# Number of tracks: 20

# %%
plt.figure(figsize=(12,6))

top_10 = df['Artist'].value_counts().head(10)

sns.countplot(
    y='Artist',
    data=df,
    order=top_10.index
)

plt.title("Top 10 Artists by Number of Tracks")
plt.xlabel("Number of Tracks")
plt.ylabel("Artist")
plt.show()

# %% [markdown]
# QUES5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track
# name for each.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd

df = pd.read_csv("spotify.csv")  
least_popular = df.sort_values(by='Popularity', ascending=True)

top5_least = least_popular[['Artist', 'Track Name', 'Popularity']].head(5)

print(top5_least)
# Out:
#              Artist                     Track Name  Popularity
# 207          Pressa  Attachments (feat. Coi Leray)          29
# 231   Justin Bieber                     Intentions          35
# 413  French Montana                Splash Brothers          44
# 435  French Montana                Splash Brothers          44
# 225        Lil Baby                  On Me - Remix          47

# %% [markdown]
# QUES6. Among the top 5 most popular artists, which artist has the highest popularity on
# average? Calculate and display the average popularity for each artist.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd

df = pd.read_csv("spotify.csv")
top5_artists = (
    df.groupby("Artist")["Popularity"]
    .mean()
    .sort_values(ascending=False)
    .head(5)
    .index
)


avg_popularity = (
    df[df["Artist"].isin(top5_artists)].groupby("Artist")["Popularity"].mean().sort_values(ascending=False)
)


print("Average Popularity of Top 5 Most Popular Artists:\n")
print(avg_popularity)
# Out:
# Average Popularity of Top 5 Most Popular Artists:
#
# Artist
# cassö           92.000000
# Trueno          89.000000
# David Guetta    87.000000
# Travis Scott    87.000000
# ¥$              86.090909
# Name: Popularity, dtype: float64

# %% [markdown]
# QUES7. For the top 5 most popular artists, what are their most popular tracks? List the track
# name for each artist.

# %% [markdown]
# <B>ANS:</B>

# %%
import pandas as pd

df = pd.read_csv("spotify.csv")
top_5_artists = (
    df.groupby("Artist")["Popularity"].mean().sort_values(ascending=False).head(5).index
)
s
top_5_df = df[df["Artist"].isin(top_5_artists)]

most_popular_tracks = (
    top_5_df.loc[top_5_df.groupby("Artist")["Popularity"].idxmax()]
    [["Artist", "Track Name", "Popularity"]]
)

print("Most Popular Track of Each Top 5 Artist:\n")
print(most_popular_tracks.sort_values(by="Popularity", ascending=False))
# Out:
# Most Popular Track of Each Top 5 Artist:
#
#            Artist                    Track Name  Popularity
# 260            ¥$                      CARNIVAL          96
# 30   Travis Scott    FE!N (feat. Playboi Carti)          93
# 140         cassö                         Prada          92
# 241        Trueno  Mamichula - con Nicki Nicole          89
# 200  David Guetta            Baby Don't Hurt Me          87

# %% [markdown]
# QUES8. Visualize relationships between multiple numerical variables simultaneously using a pair
# plot.

# %% [markdown]
# <B>ANS:</B>

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("amazon.csv")
numerical_cols = [
    "Popularity",
    "Duration (ms)",
    "Artist",
    "Track ID",
    "Track Name",
]
#Creating a pairplot
sns.pairplot(df[numerical_cols])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 12
#       4 numerical_cols = [
#       5     "Popularity",
#       6     "Duration (ms)",
#    (...)
#       9     "Track Name",
#      10 ]
#      11 #Creating a pairplot
# ---> 12 sns.pairplot(df[numerical_cols])
#      13 plt.show()
#
# File ~\.matplotlib\my anaconda\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\.matplotlib\my anaconda\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
# ...

# %% [markdown]
# QUES9. Does the duration of tracks vary significantly across different artists? Explore this visually
# using a box plot or violin plot.

# %% [markdown]
# <B>ANS:</B>

# %%
df["duration_min"] = df["Duration (ms)"] / 60000

top_artists = df["Artist"].value_counts().head(10).index
df_top = df[df["Artist"].isin(top_artists)]


plt.figure(figsize=(12,6))
sns.boxplot(x="Artist", y="duration_min", data=df_top)

plt.xticks(rotation=45)
plt.title("Distribution of Track Duration ")
plt.ylabel("Duration (min)")
plt.xlabel("Artist")
plt.show()

# %% [markdown]
# QUES10. How does the distribution of track popularity vary for different artists? Visualize this using
# a swarm plot or a violin plot.

# %% [markdown]
# <B>ANS:</B>

# %%
plt.figure(figsize=(12,6))
sns.violinplot(x="Artist", y="Popularity", data=df_top)

plt.xticks(rotation=45)
plt.title("Distribution of Track Popularity Across Top Artists")
plt.ylabel("Popularity")
plt.xlabel("Artist")
plt.show()
